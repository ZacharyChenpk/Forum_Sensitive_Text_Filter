# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

def probability_distribution(data, bins_interval=1, margin=1):
    bins = list(np.arange(min(data), max(data) + bins_interval, bins_interval))
    print(len(bins))
    #for i in range(0, len(bins)):
    #    print(bins[i])
    plt.xlim(min(data) - margin, max(data) + margin)
    plt.title("Distribution")
    plt.xlabel('Interval')
    plt.ylabel('Probability')
    prob,left,rectangle = plt.hist(x=data, bins=bins, normed=True, histtype='bar', color=['r'])
    for x, y in zip(left, prob):
        plt.text(x + bins_interval / 2, y + 0.003, '%.4f' % y, ha='center', va='top')
    plt.show()

# %%
import pickle
with open('../holes_github_dict.pkl','rb') as f:
    holes = pickle.load(f)

# %%
with open('../pids_github.pkl','rb') as f:
    pos_pids = pickle.load(f)
with open('../deleted_pids.pkl','rb') as f:
    neg_pids = pickle.load(f)
    
pos_pids = list(set(pos_pids) - set(neg_pids))

# %%
import utils
#reload(utils)
from utils import sen_parse
import pkuseg

pos_months = []
neg_months = []
pos_hours = []
neg_hours = []
pos_wordlen = []
neg_wordlen = []
pos_textlen = []
neg_textlen = []

seg = pkuseg.pkuseg(model_name='web')

# %%
for posid in pos_pids:
    hole = holes[posid]
    pos_months.append(hole['time']['month'])
    pos_hours.append(hole['time']['hour'])
    words = sen_parse(hole['dz_text'], seg)
    pos_textlen.append(len(words))
    words = [len(w) for w in words if len(w)<9]
    pos_wordlen.append(sum(words)/len(words) if len(words)>0 else -0.5)

# %%
for negid in neg_pids:
    hole = holes[negid]
    neg_months.append(hole['time']['month'])
    neg_hours.append(hole['time']['hour'])
    words = sen_parse(hole['dz_text'], seg)
    neg_textlen.append(len(words))
    words = [len(w) for w in words if len(w)<9]
    neg_wordlen.append(sum(words)/len(words) if len(words)>0 else -0.5)

# %%
#bins1 = np.arange(1, 13)
probability_distribution(data=pos_months+neg_months, bins_interval=1)
probability_distribution(data=pos_months, bins_interval=1)
probability_distribution(data=neg_months, bins_interval=1)
# Out:
# 12
# D:\Anaconda3\envs\pytorch36\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# 12
# 12

# %%
#bins2 = np.arange(25)
probability_distribution(data=pos_hours+neg_hours, bins_interval=1)
probability_distribution(data=pos_hours, bins_interval=1)
probability_distribution(data=neg_hours, bins_interval=1)
# Out:
# 24
# D:\Anaconda3\envs\pytorch36\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# 24
# 24

# %%
min_wordlen = min(min(pos_wordlen), min(neg_wordlen))
max_wordlen = max(max(pos_wordlen), max(neg_wordlen))
bins_interval = (max_wordlen-min_wordlen)/20
print(min_wordlen)
print(max_wordlen)
#bins3 = np.arange()
probability_distribution(data=pos_wordlen+neg_wordlen, bins_interval=bins_interval)
probability_distribution(data=pos_wordlen, bins_interval=bins_interval)
probability_distribution(data=neg_wordlen, bins_interval=bins_interval)

# %%
min_textlen = min(min(pos_textlen), min(neg_textlen))
max_textlen = max(max(pos_textlen), max(neg_textlen))
bins_interval = (max_textlen-min_textlen)/20
print(min_textlen)
print(max_textlen)
probability_distribution(data=pos_textlen+neg_textlen, bins_interval=bins_interval)
probability_distribution(data=pos_textlen, bins_interval=bins_interval)
probability_distribution(data=neg_textlen, bins_interval=bins_interval)
